# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression 
import joblib

# %%
df = pd.read_csv(r"D:\django\september\deploy_machinelearning_model_formation\regression_model\Linear_regression_dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1232 entries, 0 to 1231
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   var_1   1232 non-null   int64
#  1   var_2   1232 non-null   int64
#  2   var_3   1232 non-null   int64
#  3   var_4   1232 non-null   float64
#  4   var_5   1232 non-null   float64
#  5   output  1232 non-null   float64
# dtypes: float64(3), int64(3)
# memory usage: 57.9 KB

# %%
df.describe()
# Out:
#              var_1        var_2        var_3        var_4        var_5  \
# count  1232.000000  1232.000000  1232.000000  1232.000000  1232.000000
# mean    715.081981   715.081981    80.904221     0.326331     0.259273
# std      91.534294    93.079933    11.458139     0.015013     0.012907
# min     463.000000   472.000000    40.000000     0.277000     0.214000
# 25%     652.000000   649.750000    73.000000     0.317000     0.251000
# 50%     711.000000   709.000000    81.000000     0.326000     0.260000
# 75%     775.000000   774.250000    89.000000     0.337000     0.268000
# max    1009.000000  1103.000000   116.000000     0.373000     0.294000
#
#             output
# count  1232.000000
# mean      0.397342
# std       0.033267
# min       0.301000
# 25%       0.375000
# 50%       0.396000
# 75%       0.421000
# max       0.491000

# %%
df.columns
# Out:
# Index(['var_1', 'var_2', 'var_3', 'var_4', 'var_5', 'output'], dtype='object')

# %%
pd.plotting.scatter_matrix(df, figsize=(8,8));

# %%
df.hist(figsize=(8,8));

# %%
df.sample(5)
# Out:
#       var_1  var_2  var_3  var_4  var_5  output
# 328     843    882     72  0.338  0.269   0.455
# 89      655    742     69  0.318  0.250   0.390
# 1185    569    776     53  0.296  0.246   0.348
# 543     608    668     81  0.313  0.246   0.359
# 1031    663    587     89  0.325  0.266   0.370

# %%
#create X ( input variables with all columns except for outout/target column )
X=df.loc[:,df.columns !='output']

# %%
#create the y data with only output column
y=df['output']

# %%
#Train the Linear Regression model on training dataset
lr = LinearRegression().fit(X, y)

# %%
lr.score(X,y)
# Out:
# 0.8692670151914199

# %%
joblib.dump(lr,'linear_regression_model.pkl')
# Out:
# ['linear_regression_model.pkl']

# %%
test_data=[600,588,90,0.358,0.333]

# %%
pred_arr=np.array(test_data)
print(pred_arr)
preds=pred_arr.reshape(1,-1)
print(preds)
model=open("linear_regression_model.pkl","rb")
lr_model=joblib.load(model)
model_prediction=lr_model.predict(preds)
print(model_prediction)
# Out:
# [6.00e+02 5.88e+02 9.00e+01 3.58e-01 3.33e-01]
# [[6.00e+02 5.88e+02 9.00e+01 3.58e-01 3.33e-01]]
# [0.36901871]
# d:\django\september\virtualenvironment\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
